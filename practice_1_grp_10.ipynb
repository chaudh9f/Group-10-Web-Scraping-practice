# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url="https://hbkapadia.com/"

headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response=requests.get(url,headers=headers)
print("Status code:",response.status_code)

if response.status_code == 200:
  soup=BeautifulSoup(response.text,"html.parser")
  title= soup.title.text if soup.title else "title not found"

  print("\n Website Title:")
  print(title)

  links= soup.find_all("a")

  data=[]

  for link in links[:20]:
    href = link.get("href")
    text = link.text.strip()

    data.append({
        "Text":text,
        "link":href
    })

  df=pd.DataFrame(data)

  print("\n Extracted Data:")
  print(df)

  if not soup.title or not links:
      print("\n --- Debug Info ---")
      print("BEautifulSoup did not find a title or any links. ")
      print("here's a snippet of raw html content received")
      print(response.text[:500])
      print("\n --- end Debug INFO --")

  df.to_csv("HBK-link.csv",index= False)
  print("\n CSV file saved successfully!")
elif response.status_code == 403:
  print("\n access to the website was forbiden")
  print("consider trying a different user-agent or respecting `robots.txt` if scraping is allowed.")
else:
  print(f"\n failed to retrive the web page. Status code:{response.status_code}")
# Out:
# Status code: 200
#
#  Website Title:
# The Best School in Ahmedabad for Student Success | H B Kapadia
#
#  Extracted Data:
#                           Text  \
# 0
# 1
# 2
# 3                   Admissions
# 4                      In News
# 5                   Happenings
# 6                      Careers
# 7                    E-Payment
# 8                   Contact Us
# 9
# 10                        Home
# 11                 About Group
# 12                ForeFounders
# 13                     journey
# 14  Managing Trustee’s Message
# 15                        Team
# 16                Achievements
# 17                 Initiatives
# 18                    Campuses
# 19                   Shahibaug
#
#                                                  link
# 0                                          #sidr-main
# 1                 https://www.facebook.com/hbkschool/
# 2   https://www.youtube.com/channel/UCU39hPtIV0Yrt...
# 3             https://admissions.hbkapadiaschool.com/
# ...
